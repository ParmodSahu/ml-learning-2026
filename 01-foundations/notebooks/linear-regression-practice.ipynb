# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
# Data : House Size vs Price
X = np.array([[1000], [1200], [1500], [1800], [2000], [2200]])
y = np.array([200000, 240000, 300000, 360000, 400000, 440000])
# Create and train model
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
# Predictions
predictions = model.predict(X)

# %%
# Visualize
plt.figure(figsize=(10, 6))
plt.scatter(X, y, color='blue', label='Actual')
plt.plot(X, predictions, color='red', label='Predicted')
plt.xlabel('House Size (sq ft)')
plt.ylabel('Price (₹)')
plt.title('Linear Regression: House Price Prediction')
plt.legend()
plt.show()

# %%
# Print metrics
print(f"R-squared: {model.score(X, y):.4f}")
print(f"Slope (weight): {model.coef_[0]:.2f}")
print(f"Intercept (bias): {model.intercept_:.2f}")
# Out:
# R-squared: 1.0000
# Slope (weight): 200.00
# Intercept (bias): 0.00

# %%
# Print metrics
print(f"R-squared: {model.score(X, y):.4f}")
print(f"Slope (weight): {model.coef_[0]:.2f}")
print(f"Intercept (bias): {model.intercept_:.2f}")
# Out:
# R-squared: 1.0000
# Slope (weight): 200.00
# Intercept (bias): 0.00

# %%
# Predict new house
new_house = np.array([[1700]])
predicted_price = model.predict(new_house)
print(f"Predicted price for 1700 sq ft: ₹{predicted_price[0]:.0f}")
# Out:
# Predicted price for 1700 sq ft: ₹340000
